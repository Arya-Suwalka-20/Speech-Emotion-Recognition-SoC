# %% [markdown]
# -------------- Real Project Time -------------

# %% [markdown]
# Use tensorflow.keras library for models. And you are free to use chatgpt here at this stage - Yayyyyyyyy\
# Use it where you need help, not to complete the assignment lol

# %%
#import libraries
import pandas as pd
import numpy as np
import librosa 
import tensorflow as tf
import os
from sklearn.model_selection import train_test_split
# from keras.utils import to_categorical

# %% [markdown]
# Define a function to extract features from the given filename. You will have to use librosa library for this. You can vary the features however you like. The preferred features are mfcc, chroma and melspectogram.

# %%
def extract_features(filename):
    y, sr = librosa.load(filename)
    features = {}

    MFCC = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)
    chroma = librosa.feature.chroma_stft(y=y, sr=sr)
    melspec = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)
    # melspec_dB = librosa.power_to_db(melspec, ref=np.max)
    contrast = librosa.feature.spectral_contrast(y=y, sr=sr)

    features['mfcc'] = np.mean(MFCC, axis=1)
    features['chroma'] = np.mean(chroma, axis=1)
    features['melspectrogram'] = np.mean(melspec, axis=1)
    features['contrast'] = np.mean(contrast, axis=1)

    stacked_features = np.hstack([features['mfcc'], features['chroma'], features['melspectrogram'], features['contrast']])

    return stacked_features
    # return features
    pass

# %% [markdown]
# Now, load the data from the database.
#
# You can find the database from https://zenodo.org/records/1188976#.XsAXemgzaUk
#
# You need to only download the audio files and not the video files. Also, read up on the naming convention of the files from the webpage.

# %%
def load_data(test_size):
    audios = [os.path.join(os.getcwd(), "Audio_Speech_Actors"), os.path.join(os.getcwd(), "Audio_Song_Actors")]
    features = []
    emotions =[]

    for audio in audios:
        for actor in os.listdir(audio):
            actor_path = os.path.join(audio, actor)
            for audio_file in os.listdir(actor_path):
                file_path = os.path.join(actor_path, audio_file)
                feature = extract_features(file_path)
                # print(f"Feature shape extracted from {file_path}: {feature['mfcc'].shape}, {feature['chroma'].shape}, {feature['melspectrogram'].shape}")
                
                one_hot = np.zeros(8)
                emotion_code = int(audio_file.split("-")[2])
                one_hot[emotion_code-1] = 1
                features.append(feature)
                emotions.append(one_hot)

    X = np.array(features)
    y = np.array(emotions)

    # print("Total features and emotions collected:", len(X), len(y))

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    print("Training data shape:", X_train.shape)
    return X_train, X_test, y_train, y_test                

    pass

# %% [markdown]
# Use the load_data function to load data and split the data using the train_test_split function.

# %%
#split the dataset into training and testing data with testing data = 0.2 of total data
X_train, X_test, y_train, y_test = load_data(0.2)
# Out:
# Training data shape: (1961, 187)

# %% [markdown]
# Now you need to define the model for this computation.
# For this, we will use simple neural network for this.\
# The model will have a hidden layer of 300 nodes and an output layer of [number of emotions] nodes.\
# You have to use relu as activation function for the hidden layer and softmax for the output layer.\
# Keep the loss categorical-crossentropy, optimizer as adam and accuracy as metric.\
# You can use batch-size as 256 and epochs as 300, but it is left upto you :)

# %%
#define the model.
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint
from keras.regularizers import l2
from keras.optimizers import Adam

model = Sequential()
model.add(Dense(300, input_shape=(X_train.shape[1],), activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
# model.add(Dense(250, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))
model.add(Dense(200, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
# model.add(Dense(150, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))
model.add(Dense(100, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))


optimizer = Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'] )
model.summary()

# callbacks = [
#     # EarlyStopping(monitor='val_loss', patience=0, restore_best_weights=True),  # Stop training if no improvement for 10 epochs
#     ModelCheckpoint(filepath='best_model.keras', monitor='val_accuracy', save_best_only=True),  # Save the best model based on validation accuracy
#     # ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1)  # Reduce learning rate if validation loss plateaus
# ]

checkpoint_callback = ModelCheckpoint(filepath='best_model.keras', monitor='val_accuracy', save_best_only=True)

def lr_scheduler(epoch):
    if epoch < 50:
        return 0.001
    elif epoch < 100:
        return 0.0005
    else:
        return 0.0001

lr_schedule = LearningRateScheduler(lr_scheduler)
# Out:
# c:\Users\aryas\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_77"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_229 (Dense)               │ (None, 300)            │        56,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_126         │ (None, 300)            │         1,200 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_103 (Dropout)           │ (None, 300)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_230 (Dense)               │ (None, 200)            │        60,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_127         │ (None, 200)            │           800 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_104 (Dropout)           │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_231 (Dense)               │ (None, 100)            │        20,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_128         │ (None, 100)            │           400 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_105 (Dropout)           │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_232 (Dense)               │ (None, 8)              │           808 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 139,908 (546.52 KB)
#  Trainable params: 138,708 (541.83 KB)
#  Non-trainable params: 1,200 (4.69 KB)

# %% [markdown]
# Now everything is easy-peezy. Just fit the model on training data as you usually do, predict for the testing data, print the accuracy. Hehe

# %%
#fit the model on training data with validation split of 0.2
model.fit(X_train, y_train, batch_size=256, epochs=1000, validation_split=0.2, callbacks=[lr_schedule, checkpoint_callback])
# Out:
# Epoch 1/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.1454 - loss: 3.1002 - val_accuracy: 0.1679 - val_loss: 36.9522 - learning_rate: 0.0010
# Epoch 2/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.2002 - loss: 2.5970 - val_accuracy: 0.1679 - val_loss: 29.3641 - learning_rate: 0.0010
# Epoch 3/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.2449 - loss: 2.3948 - val_accuracy: 0.1679 - val_loss: 21.2360 - learning_rate: 0.0010
# Epoch 4/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.2416 - loss: 2.4369 - val_accuracy: 0.1679 - val_loss: 15.5242 - learning_rate: 0.0010
# Epoch 5/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2360 - loss: 2.3909 - val_accuracy: 0.1679 - val_loss: 13.6305 - learning_rate: 0.0010
# Epoch 6/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.2848 - loss: 2.1369 - val_accuracy: 0.1679 - val_loss: 12.8649 - learning_rate: 0.0010
# Epoch 7/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2672 - loss: 2.0765 - val_accuracy: 0.1705 - val_loss: 11.1916 - learning_rate: 0.0010
# Epoch 8/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.2967 - loss: 2.0406 - val_accuracy: 0.1934 - val_loss: 9.4511 - learning_rate: 0.0010
# Epoch 9/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.2744 - loss: 2.0657 - val_accuracy: 0.1883 - val_loss: 8.0458 - learning_rate: 0.0010
# Epoch 10/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3076 - loss: 1.9919 - val_accuracy: 0.1908 - val_loss: 7.3400 - learning_rate: 0.0010
# Epoch 11/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2719 - loss: 2.0498 - val_accuracy: 0.1781 - val_loss: 7.1573 - learning_rate: 0.0010
# Epoch 12/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3181 - loss: 1.9329 - val_accuracy: 0.1730 - val_loss: 7.0792 - learning_rate: 0.0010
# Epoch 13/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3260 - loss: 1.8431 - val_accuracy: 0.1807 - val_loss: 6.5524 - learning_rate: 0.0010
# Epoch 14/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3169 - loss: 1.8888 - val_accuracy: 0.1858 - val_loss: 5.8563 - learning_rate: 0.0010
# Epoch 15/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3081 - loss: 1.8647 - val_accuracy: 0.1858 - val_loss: 5.3065 - learning_rate: 0.0010
# Epoch 16/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3142 - loss: 1.8706 - val_accuracy: 0.2036 - val_loss: 4.7633 - learning_rate: 0.0010
# Epoch 17/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3376 - loss: 1.8338 - val_accuracy: 0.1985 - val_loss: 4.1379 - learning_rate: 0.0010
# Epoch 18/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3447 - loss: 1.7842 - val_accuracy: 0.2188 - val_loss: 3.6105 - learning_rate: 0.0010
# Epoch 19/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3348 - loss: 1.7801 - val_accuracy: 0.2265 - val_loss: 3.1035 - learning_rate: 0.0010
# Epoch 20/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3246 - loss: 1.8510 - val_accuracy: 0.2570 - val_loss: 2.5574 - learning_rate: 0.0010
# Epoch 21/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3414 - loss: 1.7761 - val_accuracy: 0.2875 - val_loss: 2.2086 - learning_rate: 0.0010
# Epoch 22/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3663 - loss: 1.6828 - val_accuracy: 0.3028 - val_loss: 2.1353 - learning_rate: 0.0010
# Epoch 23/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3749 - loss: 1.6271 - val_accuracy: 0.3206 - val_loss: 2.1163 - learning_rate: 0.0010
# Epoch 24/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3858 - loss: 1.6637 - val_accuracy: 0.3410 - val_loss: 1.9995 - learning_rate: 0.0010
# Epoch 25/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3995 - loss: 1.6566 - val_accuracy: 0.3562 - val_loss: 1.8596 - learning_rate: 0.0010
# Epoch 26/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.3890 - loss: 1.6448 - val_accuracy: 0.3740 - val_loss: 1.7196 - learning_rate: 0.0010
# Epoch 27/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3916 - loss: 1.5734 - val_accuracy: 0.3715 - val_loss: 1.6342 - learning_rate: 0.0010
# Epoch 28/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3885 - loss: 1.6163 - val_accuracy: 0.3639 - val_loss: 1.5875 - learning_rate: 0.0010
# Epoch 29/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4038 - loss: 1.5785 - val_accuracy: 0.3664 - val_loss: 1.5603 - learning_rate: 0.0010
# Epoch 30/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4415 - loss: 1.5104 - val_accuracy: 0.3740 - val_loss: 1.5668 - learning_rate: 0.0010
# Epoch 31/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4088 - loss: 1.5509 - val_accuracy: 0.3868 - val_loss: 1.5687 - learning_rate: 0.0010
# Epoch 32/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4235 - loss: 1.5288 - val_accuracy: 0.3893 - val_loss: 1.5482 - learning_rate: 0.0010
# Epoch 33/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4139 - loss: 1.4884 - val_accuracy: 0.3740 - val_loss: 1.5119 - learning_rate: 0.0010
# Epoch 34/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4245 - loss: 1.4942 - val_accuracy: 0.3842 - val_loss: 1.4907 - learning_rate: 0.0010
# Epoch 35/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4231 - loss: 1.4984 - val_accuracy: 0.3842 - val_loss: 1.4944 - learning_rate: 0.0010
# Epoch 36/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4394 - loss: 1.4691 - val_accuracy: 0.3919 - val_loss: 1.5582 - learning_rate: 0.0010
# Epoch 37/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4209 - loss: 1.4650 - val_accuracy: 0.3511 - val_loss: 1.5971 - learning_rate: 0.0010
# Epoch 38/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4551 - loss: 1.4003 - val_accuracy: 0.3690 - val_loss: 1.6357 - learning_rate: 0.0010
# Epoch 39/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4592 - loss: 1.4055 - val_accuracy: 0.3410 - val_loss: 1.7157 - learning_rate: 0.0010
# Epoch 40/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4504 - loss: 1.4050 - val_accuracy: 0.3104 - val_loss: 1.8020 - learning_rate: 0.0010
# Epoch 41/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4527 - loss: 1.4106 - val_accuracy: 0.3181 - val_loss: 1.7866 - learning_rate: 0.0010
# Epoch 42/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4578 - loss: 1.4156 - val_accuracy: 0.3206 - val_loss: 1.7385 - learning_rate: 0.0010
# Epoch 43/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4763 - loss: 1.3970 - val_accuracy: 0.3333 - val_loss: 1.6521 - learning_rate: 0.0010
# Epoch 44/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4573 - loss: 1.3859 - val_accuracy: 0.3486 - val_loss: 1.6458 - learning_rate: 0.0010
# Epoch 45/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4645 - loss: 1.3623 - val_accuracy: 0.3511 - val_loss: 1.6776 - learning_rate: 0.0010
# Epoch 46/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4713 - loss: 1.3663 - val_accuracy: 0.3461 - val_loss: 1.6968 - learning_rate: 0.0010
# Epoch 47/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4792 - loss: 1.3790 - val_accuracy: 0.3384 - val_loss: 1.8024 - learning_rate: 0.0010
# Epoch 48/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4998 - loss: 1.3392 - val_accuracy: 0.3079 - val_loss: 1.8731 - learning_rate: 0.0010
# Epoch 49/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5036 - loss: 1.3173 - val_accuracy: 0.3053 - val_loss: 1.8231 - learning_rate: 0.0010
# Epoch 50/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4992 - loss: 1.2856 - val_accuracy: 0.3003 - val_loss: 1.8715 - learning_rate: 0.0010
# Epoch 51/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5137 - loss: 1.3223 - val_accuracy: 0.2901 - val_loss: 1.8688 - learning_rate: 5.0000e-04
# Epoch 52/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5084 - loss: 1.2874 - val_accuracy: 0.3003 - val_loss: 1.8150 - learning_rate: 5.0000e-04
# Epoch 53/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4966 - loss: 1.2934 - val_accuracy: 0.3257 - val_loss: 1.6677 - learning_rate: 5.0000e-04
# Epoch 54/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5398 - loss: 1.2616 - val_accuracy: 0.3537 - val_loss: 1.5706 - learning_rate: 5.0000e-04
# Epoch 55/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5136 - loss: 1.2884 - val_accuracy: 0.3664 - val_loss: 1.5438 - learning_rate: 5.0000e-04
# Epoch 56/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5247 - loss: 1.2570 - val_accuracy: 0.3435 - val_loss: 1.6416 - learning_rate: 5.0000e-04
# Epoch 57/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5240 - loss: 1.2479 - val_accuracy: 0.3130 - val_loss: 1.8104 - learning_rate: 5.0000e-04
# Epoch 58/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4899 - loss: 1.2917 - val_accuracy: 0.3206 - val_loss: 1.7450 - learning_rate: 5.0000e-04
# Epoch 59/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5284 - loss: 1.2724 - val_accuracy: 0.3232 - val_loss: 1.6650 - learning_rate: 5.0000e-04
# Epoch 60/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5211 - loss: 1.2696 - val_accuracy: 0.3308 - val_loss: 1.6269 - learning_rate: 5.0000e-04
# Epoch 61/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5085 - loss: 1.3088 - val_accuracy: 0.3537 - val_loss: 1.5573 - learning_rate: 5.0000e-04
# Epoch 62/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5351 - loss: 1.2695 - val_accuracy: 0.3868 - val_loss: 1.5305 - learning_rate: 5.0000e-04
# Epoch 63/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5130 - loss: 1.2561 - val_accuracy: 0.4148 - val_loss: 1.5286 - learning_rate: 5.0000e-04
# Epoch 64/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5247 - loss: 1.2362 - val_accuracy: 0.4300 - val_loss: 1.5250 - learning_rate: 5.0000e-04
# Epoch 65/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5397 - loss: 1.2233 - val_accuracy: 0.4453 - val_loss: 1.4895 - learning_rate: 5.0000e-04
# Epoch 66/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5309 - loss: 1.2298 - val_accuracy: 0.4377 - val_loss: 1.4688 - learning_rate: 5.0000e-04
# Epoch 67/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5043 - loss: 1.2381 - val_accuracy: 0.4555 - val_loss: 1.4128 - learning_rate: 5.0000e-04
# Epoch 68/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5269 - loss: 1.2199 - val_accuracy: 0.4275 - val_loss: 1.4235 - learning_rate: 5.0000e-04
# Epoch 69/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5182 - loss: 1.2268 - val_accuracy: 0.4020 - val_loss: 1.4818 - learning_rate: 5.0000e-04
# Epoch 70/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5628 - loss: 1.2141 - val_accuracy: 0.3842 - val_loss: 1.5214 - learning_rate: 5.0000e-04
# Epoch 71/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5404 - loss: 1.2129 - val_accuracy: 0.4020 - val_loss: 1.5103 - learning_rate: 5.0000e-04
# Epoch 72/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5262 - loss: 1.2172 - val_accuracy: 0.4122 - val_loss: 1.4975 - learning_rate: 5.0000e-04
# Epoch 73/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5596 - loss: 1.1806 - val_accuracy: 0.4020 - val_loss: 1.5136 - learning_rate: 5.0000e-04
# Epoch 74/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5638 - loss: 1.2001 - val_accuracy: 0.4097 - val_loss: 1.4795 - learning_rate: 5.0000e-04
# Epoch 75/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5375 - loss: 1.2154 - val_accuracy: 0.4326 - val_loss: 1.4902 - learning_rate: 5.0000e-04
# Epoch 76/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5574 - loss: 1.1833 - val_accuracy: 0.4555 - val_loss: 1.4190 - learning_rate: 5.0000e-04
# Epoch 77/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5239 - loss: 1.2131 - val_accuracy: 0.4911 - val_loss: 1.3221 - learning_rate: 5.0000e-04
# Epoch 78/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5415 - loss: 1.2080 - val_accuracy: 0.4758 - val_loss: 1.3637 - learning_rate: 5.0000e-04
# Epoch 79/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5475 - loss: 1.1819 - val_accuracy: 0.4707 - val_loss: 1.3910 - learning_rate: 5.0000e-04
# Epoch 80/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5394 - loss: 1.1807 - val_accuracy: 0.4758 - val_loss: 1.3751 - learning_rate: 5.0000e-04
# Epoch 81/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5663 - loss: 1.1616 - val_accuracy: 0.4682 - val_loss: 1.4081 - learning_rate: 5.0000e-04
# Epoch 82/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5454 - loss: 1.1738 - val_accuracy: 0.4275 - val_loss: 1.5837 - learning_rate: 5.0000e-04
# Epoch 83/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5495 - loss: 1.1644 - val_accuracy: 0.3944 - val_loss: 1.7040 - learning_rate: 5.0000e-04
# Epoch 84/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5372 - loss: 1.1870 - val_accuracy: 0.4326 - val_loss: 1.6089 - learning_rate: 5.0000e-04
# Epoch 85/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5362 - loss: 1.2022 - val_accuracy: 0.4351 - val_loss: 1.5302 - learning_rate: 5.0000e-04
# Epoch 86/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5401 - loss: 1.2171 - val_accuracy: 0.4377 - val_loss: 1.5226 - learning_rate: 5.0000e-04
# Epoch 87/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5728 - loss: 1.1306 - val_accuracy: 0.4402 - val_loss: 1.5392 - learning_rate: 5.0000e-04
# Epoch 88/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5675 - loss: 1.1601 - val_accuracy: 0.4427 - val_loss: 1.5071 - learning_rate: 5.0000e-04
# Epoch 89/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5684 - loss: 1.1306 - val_accuracy: 0.4249 - val_loss: 1.5008 - learning_rate: 5.0000e-04
# Epoch 90/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5680 - loss: 1.1515 - val_accuracy: 0.4122 - val_loss: 1.5230 - learning_rate: 5.0000e-04
# Epoch 91/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5630 - loss: 1.1560 - val_accuracy: 0.4020 - val_loss: 1.5391 - learning_rate: 5.0000e-04
# Epoch 92/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5495 - loss: 1.1636 - val_accuracy: 0.3817 - val_loss: 1.6293 - learning_rate: 5.0000e-04
# Epoch 93/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5645 - loss: 1.1723 - val_accuracy: 0.4173 - val_loss: 1.5400 - learning_rate: 5.0000e-04
# Epoch 94/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5695 - loss: 1.1580 - val_accuracy: 0.5013 - val_loss: 1.3275 - learning_rate: 5.0000e-04
# Epoch 95/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5672 - loss: 1.1410 - val_accuracy: 0.5115 - val_loss: 1.2491 - learning_rate: 5.0000e-04
# Epoch 96/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5530 - loss: 1.1487 - val_accuracy: 0.5369 - val_loss: 1.1779 - learning_rate: 5.0000e-04
# Epoch 97/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5771 - loss: 1.1218 - val_accuracy: 0.5140 - val_loss: 1.2089 - learning_rate: 5.0000e-04
# Epoch 98/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5619 - loss: 1.1622 - val_accuracy: 0.5064 - val_loss: 1.2601 - learning_rate: 5.0000e-04
# Epoch 99/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5768 - loss: 1.1263 - val_accuracy: 0.4860 - val_loss: 1.3135 - learning_rate: 5.0000e-04
# Epoch 100/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5823 - loss: 1.1072 - val_accuracy: 0.5115 - val_loss: 1.2608 - learning_rate: 5.0000e-04
# Epoch 101/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5699 - loss: 1.1444 - val_accuracy: 0.5140 - val_loss: 1.2350 - learning_rate: 1.0000e-04
# Epoch 102/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5502 - loss: 1.1530 - val_accuracy: 0.5165 - val_loss: 1.2136 - learning_rate: 1.0000e-04
# Epoch 103/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5905 - loss: 1.1190 - val_accuracy: 0.5267 - val_loss: 1.1896 - learning_rate: 1.0000e-04
# Epoch 104/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5836 - loss: 1.1502 - val_accuracy: 0.5293 - val_loss: 1.1758 - learning_rate: 1.0000e-04
# Epoch 105/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5713 - loss: 1.1285 - val_accuracy: 0.5420 - val_loss: 1.1522 - learning_rate: 1.0000e-04
# Epoch 106/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5681 - loss: 1.1501 - val_accuracy: 0.5496 - val_loss: 1.1382 - learning_rate: 1.0000e-04
# Epoch 107/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5649 - loss: 1.1353 - val_accuracy: 0.5522 - val_loss: 1.1275 - learning_rate: 1.0000e-04
# Epoch 108/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5748 - loss: 1.1314 - val_accuracy: 0.5598 - val_loss: 1.1156 - learning_rate: 1.0000e-04
# Epoch 109/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5575 - loss: 1.1525 - val_accuracy: 0.5598 - val_loss: 1.1134 - learning_rate: 1.0000e-04
# Epoch 110/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5732 - loss: 1.1415 - val_accuracy: 0.5623 - val_loss: 1.1130 - learning_rate: 1.0000e-04
# Epoch 111/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5863 - loss: 1.1046 - val_accuracy: 0.5445 - val_loss: 1.1193 - learning_rate: 1.0000e-04
# Epoch 112/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5614 - loss: 1.1242 - val_accuracy: 0.5293 - val_loss: 1.1330 - learning_rate: 1.0000e-04
# Epoch 113/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5959 - loss: 1.1209 - val_accuracy: 0.5191 - val_loss: 1.1315 - learning_rate: 1.0000e-04
# Epoch 114/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5777 - loss: 1.1285 - val_accuracy: 0.5369 - val_loss: 1.1113 - learning_rate: 1.0000e-04
# Epoch 115/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.
- learning_rate: 1.0000e-04
# Epoch 301/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6152 - loss: 1.0179 - val_accuracy: 0.6107 - val_loss: 1.0067 - learning_rate: 1.0000e-04
# Epoch 302/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6080 - loss: 1.0123 - val_accuracy: 0.6158 - val_loss: 0.9965 - learning_rate: 1.0000e-04
# Epoch 303/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6197 - loss: 1.0198 - val_accuracy: 0.6158 - val_loss: 0.9915 - learning_rate: 1.0000e-04
# Epoch 304/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6289 - loss: 0.9717 - val_accuracy: 0.6158 - val_loss: 0.9905 - learning_rate: 1.0000e-04
# Epoch 305/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6267 - loss: 0.9912 - val_accuracy: 0.6183 - val_loss: 0.9879 - learning_rate: 1.0000e-04
# Epoch 306/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6118 - loss: 1.0008 - val_accuracy: 0.6310 - val_loss: 0.9875 - learning_rate: 1.0000e-04
# Epoch 307/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6067 - loss: 1.0290 - val_accuracy: 0.6234 - val_loss: 0.9890 - learning_rate: 1.0000e-04
# Epoch 308/1000
# ...
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6983 - loss: 0.7811 - val_accuracy: 0.6336 - val_loss: 0.9526 - learning_rate: 1.0000e-04
# Epoch 900/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6804 - loss: 0.8331 - val_accuracy: 0.6565 - val_loss: 0.9513 - learning_rate: 1.0000e-04
# Epoch 901/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6898 - loss: 0.8195 - val_accuracy: 0.6616 - val_loss: 0.9518 - learning_rate: 1.0000e-04
# Epoch 902/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7153 - loss: 0.7736 - val_accuracy: 0.6641 - val_loss: 0.9532 - learning_rate: 1.0000e-04
# Epoch 903/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6875 - loss: 0.8370 - val_accuracy: 0.6667 - val_loss: 0.9510 - learning_rate: 1.0000e-04
# Epoch 904/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7124 - loss: 0.7784 - val_accuracy: 0.6616 - val_loss: 0.9507 - learning_rate: 1.0000e-04
# Epoch 905/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7078 - loss: 0.7860 - val_accuracy: 0.6590 - val_loss: 0.9521 - learning_rate: 1.0000e-04
# Epoch 906/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7034 - loss: 0.7765 - val_accuracy: 0.6489 - val_loss: 0.9585 - learning_rate: 1.0000e-04
# Epoch 907/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7132 - loss: 0.8194 - val_accuracy: 0.6514 - val_loss: 0.9680 - learning_rate: 1.0000e-04
# Epoch 908/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7049 - loss: 0.7921 - val_accuracy: 0.6438 - val_loss: 0.9783 - learning_rate: 1.0000e-04
# Epoch 909/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7122 - loss: 0.7881 - val_accuracy: 0.6489 - val_loss: 0.9887 - learning_rate: 1.0000e-04
# Epoch 910/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7128 - loss: 0.7911 - val_accuracy: 0.6514 - val_loss: 0.9911 - learning_rate: 1.0000e-04
# Epoch 911/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7186 - loss: 0.7771 - val_accuracy: 0.6438 - val_loss: 0.9968 - learning_rate: 1.0000e-04
# Epoch 912/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7003 - loss: 0.8088 - val_accuracy: 0.6438 - val_loss: 0.9987 - learning_rate: 1.0000e-04
# Epoch 913/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6917 - loss: 0.8168 - val_accuracy: 0.6387 - val_loss: 0.9895 - learning_rate: 1.0000e-04
# Epoch 914/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6913 - loss: 0.8025 - val_accuracy: 0.6361 - val_loss: 0.9792 - learning_rate: 1.0000e-04
# Epoch 915/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7079 - loss: 0.7659 - val_accuracy: 0.6412 - val_loss: 0.9673 - learning_rate: 1.0000e-04
# Epoch 916/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6998 - loss: 0.7970 - val_accuracy: 0.6438 - val_loss: 0.9600 - learning_rate: 1.0000e-04
# Epoch 917/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7006 - loss: 0.7770 - val_accuracy: 0.6438 - val_loss: 0.9648 - learning_rate: 1.0000e-04
# Epoch 918/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6895 - loss: 0.8420 - val_accuracy: 0.6463 - val_loss: 0.9697 - learning_rate: 1.0000e-04
# Epoch 919/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6967 - loss: 0.8124 - val_accuracy: 0.6514 - val_loss: 0.9699 - learning_rate: 1.0000e-04
# Epoch 920/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6911 - loss: 0.8161 - val_accuracy: 0.6463 - val_loss: 0.9629 - learning_rate: 1.0000e-04
# Epoch 921/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6950 - loss: 0.8163 - val_accuracy: 0.6489 - val_loss: 0.9654 - learning_rate: 1.0000e-04
# Epoch 922/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7007 - loss: 0.7730 - val_accuracy: 0.6565 - val_loss: 0.9641 - learning_rate: 1.0000e-04
# Epoch 923/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7193 - loss: 0.7810 - val_accuracy: 0.6539 - val_loss: 0.9650 - learning_rate: 1.0000e-04
# Epoch 924/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6994 - loss: 0.8152 - val_accuracy: 0.6565 - val_loss: 0.9708 - learning_rate: 1.0000e-04
# Epoch 925/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7080 - loss: 0.7654 - val_accuracy: 0.6539 - val_loss: 0.9723 - learning_rate: 1.0000e-04
# Epoch 926/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7080 - loss: 0.7871 - val_accuracy: 0.6489 - val_loss: 0.9724 - learning_rate: 1.0000e-04
# Epoch 927/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6947 - loss: 0.8049 - val_accuracy: 0.6463 - val_loss: 0.9699 - learning_rate: 1.0000e-04
# Epoch 928/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6954 - loss: 0.8084 - val_accuracy: 0.6514 - val_loss: 0.9650 - learning_rate: 1.0000e-04
# Epoch 929/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7127 - loss: 0.7819 - val_accuracy: 0.6565 - val_loss: 0.9672 - learning_rate: 1.0000e-04
# Epoch 930/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7042 - loss: 0.7888 - val_accuracy: 0.6565 - val_loss: 0.9674 - learning_rate: 1.0000e-04
# Epoch 931/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7057 - loss: 0.7921 - val_accuracy: 0.6565 - val_loss: 0.9635 - learning_rate: 1.0000e-04
# Epoch 932/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7233 - loss: 0.7592 - val_accuracy: 0.6616 - val_loss: 0.9573 - learning_rate: 1.0000e-04
# Epoch 933/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7091 - loss: 0.7834 - val_accuracy: 0.6514 - val_loss: 0.9635 - learning_rate: 1.0000e-04
# Epoch 934/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6992 - loss: 0.7911 - val_accuracy: 0.6438 - val_loss: 0.9654 - learning_rate: 1.0000e-04
# Epoch 935/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7165 - loss: 0.7800 - val_accuracy: 0.6590 - val_loss: 0.9598 - learning_rate: 1.0000e-04
# Epoch 936/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6974 - loss: 0.8232 - val_accuracy: 0.6590 - val_loss: 0.9539 - learning_rate: 1.0000e-04
# Epoch 937/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6965 - loss: 0.8188 - val_accuracy: 0.6590 - val_loss: 0.9471 - learning_rate: 1.0000e-04
# Epoch 938/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6930 - loss: 0.8037 - val_accuracy: 0.6539 - val_loss: 0.9435 - learning_rate: 1.0000e-04
# Epoch 939/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7232 - loss: 0.7665 - val_accuracy: 0.6539 - val_loss: 0.9414 - learning_rate: 1.0000e-04
# Epoch 940/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7049 - loss: 0.7824 - val_accuracy: 0.6565 - val_loss: 0.9412 - learning_rate: 1.0000e-04
# Epoch 941/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7240 - loss: 0.7790 - val_accuracy: 0.6667 - val_loss: 0.9478 - learning_rate: 1.0000e-04
# Epoch 942/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6805 - loss: 0.7990 - val_accuracy: 0.6565 - val_loss: 0.9589 - learning_rate: 1.0000e-04
# Epoch 943/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7241 - loss: 0.7947 - val_accuracy: 0.6616 - val_loss: 0.9604 - learning_rate: 1.0000e-04
# Epoch 944/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7162 - loss: 0.7684 - val_accuracy: 0.6616 - val_loss: 0.9613 - learning_rate: 1.0000e-04
# Epoch 945/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7037 - loss: 0.7799 - val_accuracy: 0.6590 - val_loss: 0.9588 - learning_rate: 1.0000e-04
# Epoch 946/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7040 - loss: 0.8126 - val_accuracy: 0.6590 - val_loss: 0.9527 - learning_rate: 1.0000e-04
# Epoch 947/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7034 - loss: 0.8004 - val_accuracy: 0.6641 - val_loss: 0.9481 - learning_rate: 1.0000e-04
# Epoch 948/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7172 - loss: 0.7619 - val_accuracy: 0.6667 - val_loss: 0.9462 - learning_rate: 1.0000e-04
# Epoch 949/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7165 - loss: 0.7903 - val_accuracy: 0.6565 - val_loss: 0.9499 - learning_rate: 1.0000e-04
# Epoch 950/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7018 - loss: 0.7951 - val_accuracy: 0.6590 - val_loss: 0.9477 - learning_rate: 1.0000e-04
# Epoch 951/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7249 - loss: 0.7607 - val_accuracy: 0.6590 - val_loss: 0.9429 - learning_rate: 1.0000e-04
# Epoch 952/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7165 - loss: 0.7628 - val_accuracy: 0.6539 - val_loss: 0.9368 - learning_rate: 1.0000e-04
# Epoch 953/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7079 - loss: 0.7923 - val_accuracy: 0.6514 - val_loss: 0.9350 - learning_rate: 1.0000e-04
# Epoch 954/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6956 - loss: 0.7781 - val_accuracy: 0.6489 - val_loss: 0.9388 - learning_rate: 1.0000e-04
# Epoch 955/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7156 - loss: 0.7670 - val_accuracy: 0.6412 - val_loss: 0.9427 - learning_rate: 1.0000e-04
# Epoch 956/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7084 - loss: 0.7870 - val_accuracy: 0.6412 - val_loss: 0.9447 - learning_rate: 1.0000e-04
# Epoch 957/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6815 - loss: 0.8091 - val_accuracy: 0.6463 - val_loss: 0.9451 - learning_rate: 1.0000e-04
# Epoch 958/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7010 - loss: 0.7980 - val_accuracy: 0.6387 - val_loss: 0.9465 - learning_rate: 1.0000e-04
# Epoch 959/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7109 - loss: 0.7863 - val_accuracy: 0.6387 - val_loss: 0.9491 - learning_rate: 1.0000e-04
# Epoch 960/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6948 - loss: 0.8138 - val_accuracy: 0.6387 - val_loss: 0.9507 - learning_rate: 1.0000e-04
# Epoch 961/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7036 - loss: 0.7961 - val_accuracy: 0.6412 - val_loss: 0.9512 - learning_rate: 1.0000e-04
# Epoch 962/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7296 - loss: 0.7576 - val_accuracy: 0.6387 - val_loss: 0.9561 - learning_rate: 1.0000e-04
# Epoch 963/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7046 - loss: 0.8280 - val_accuracy: 0.6361 - val_loss: 0.9664 - learning_rate: 1.0000e-04
# Epoch 964/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7159 - loss: 0.7909 - val_accuracy: 0.6412 - val_loss: 0.9672 - learning_rate: 1.0000e-04
# Epoch 965/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6951 - loss: 0.8030 - val_accuracy: 0.6514 - val_loss: 0.9612 - learning_rate: 1.0000e-04
# Epoch 966/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6989 - loss: 0.8055 - val_accuracy: 0.6641 - val_loss: 0.9588 - learning_rate: 1.0000e-04
# Epoch 967/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7049 - loss: 0.7942 - val_accuracy: 0.6590 - val_loss: 0.9553 - learning_rate: 1.0000e-04
# Epoch 968/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7307 - loss: 0.7545 - val_accuracy: 0.6539 - val_loss: 0.9519 - learning_rate: 1.0000e-04
# Epoch 969/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7078 - loss: 0.7898 - val_accuracy: 0.6387 - val_loss: 0.9540 - learning_rate: 1.0000e-04
# Epoch 970/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6968 - loss: 0.8129 - val_accuracy: 0.6489 - val_loss: 0.9535 - learning_rate: 1.0000e-04
# Epoch 971/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7226 - loss: 0.7691 - val_accuracy: 0.6539 - val_loss: 0.9490 - learning_rate: 1.0000e-04
# Epoch 972/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7084 - loss: 0.8028 - val_accuracy: 0.6565 - val_loss: 0.9437 - learning_rate: 1.0000e-04
# Epoch 973/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7165 - loss: 0.7625 - val_accuracy: 0.6489 - val_loss: 0.9416 - learning_rate: 1.0000e-04
# Epoch 974/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7030 - loss: 0.8019 - val_accuracy: 0.6565 - val_loss: 0.9394 - learning_rate: 1.0000e-04
# Epoch 975/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7160 - loss: 0.7567 - val_accuracy: 0.6539 - val_loss: 0.9418 - learning_rate: 1.0000e-04
# Epoch 976/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7201 - loss: 0.7651 - val_accuracy: 0.6539 - val_loss: 0.9440 - learning_rate: 1.0000e-04
# Epoch 977/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7061 - loss: 0.8012 - val_accuracy: 0.6539 - val_loss: 0.9454 - learning_rate: 1.0000e-04
# Epoch 978/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7136 - loss: 0.7667 - val_accuracy: 0.6565 - val_loss: 0.9480 - learning_rate: 1.0000e-04
# Epoch 979/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7013 - loss: 0.7974 - val_accuracy: 0.6590 - val_loss: 0.9496 - learning_rate: 1.0000e-04
# Epoch 980/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7158 - loss: 0.7807 - val_accuracy: 0.6565 - val_loss: 0.9494 - learning_rate: 1.0000e-04
# Epoch 981/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6931 - loss: 0.8266 - val_accuracy: 0.6539 - val_loss: 0.9475 - learning_rate: 1.0000e-04
# Epoch 982/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6862 - loss: 0.7971 - val_accuracy: 0.6590 - val_loss: 0.9538 - learning_rate: 1.0000e-04
# Epoch 983/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7044 - loss: 0.7633 - val_accuracy: 0.6590 - val_loss: 0.9574 - learning_rate: 1.0000e-04
# Epoch 984/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7186 - loss: 0.7818 - val_accuracy: 0.6590 - val_loss: 0.9548 - learning_rate: 1.0000e-04
# Epoch 985/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7181 - loss: 0.7693 - val_accuracy: 0.6539 - val_loss: 0.9508 - learning_rate: 1.0000e-04
# Epoch 986/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7256 - loss: 0.7428 - val_accuracy: 0.6514 - val_loss: 0.9501 - learning_rate: 1.0000e-04
# Epoch 987/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7010 - loss: 0.7870 - val_accuracy: 0.6489 - val_loss: 0.9536 - learning_rate: 1.0000e-04
# Epoch 988/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6848 - loss: 0.8194 - val_accuracy: 0.6514 - val_loss: 0.9603 - learning_rate: 1.0000e-04
# Epoch 989/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7086 - loss: 0.7646 - val_accuracy: 0.6539 - val_loss: 0.9622 - learning_rate: 1.0000e-04
# Epoch 990/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7147 - loss: 0.7909 - val_accuracy: 0.6438 - val_loss: 0.9585 - learning_rate: 1.0000e-04
# Epoch 991/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7285 - loss: 0.7561 - val_accuracy: 0.6387 - val_loss: 0.9583 - learning_rate: 1.0000e-04
# Epoch 992/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7204 - loss: 0.7911 - val_accuracy: 0.6463 - val_loss: 0.9536 - learning_rate: 1.0000e-04
# Epoch 993/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7063 - loss: 0.7941 - val_accuracy: 0.6514 - val_loss: 0.9469 - learning_rate: 1.0000e-04
# Epoch 994/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6897 - loss: 0.8078 - val_accuracy: 0.6565 - val_loss: 0.9446 - learning_rate: 1.0000e-04
# Epoch 995/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7091 - loss: 0.7782 - val_accuracy: 0.6539 - val_loss: 0.9482 - learning_rate: 1.0000e-04
# Epoch 996/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7034 - loss: 0.7837 - val_accuracy: 0.6539 - val_loss: 0.9537 - learning_rate: 1.0000e-04
# Epoch 997/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7131 - loss: 0.7718 - val_accuracy: 0.6514 - val_loss: 0.9532 - learning_rate: 1.0000e-04
# Epoch 998/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7146 - loss: 0.7779 - val_accuracy: 0.6514 - val_loss: 0.9511 - learning_rate: 1.0000e-04
# Epoch 999/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7061 - loss: 0.8055 - val_accuracy: 0.6463 - val_loss: 0.9553 - learning_rate: 1.0000e-04
# Epoch 1000/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7151 - loss: 0.7626 - val_accuracy: 0.6565 - val_loss: 0.9672 - learning_rate: 1.0000e-04

# %%
#predict for testing data and printout the accuracy
from sklearn.metrics import accuracy_score
y_pred = model.predict(X_test)
accuracy = accuracy_score(np.argmax(y_test, axis = 1), np.argmax(y_pred, axis = 1))
percent = accuracy*100
print(f"Accuracy: {percent:.2f}%")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Accuracy: 70.47%

# %% [markdown]
# Now comes the learning part :)\
# Here's a new thing. Print the classification report of your predictions.

# %%
#print the classification report for the model
from sklearn.metrics import classification_report
report = classification_report(np.argmax(y_test, axis = 1), np.argmax(y_pred, axis = 1))
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.72      0.70        36
#            1       0.83      0.74      0.78        84
#            2       0.68      0.69      0.69        68
#            3       0.61      0.64      0.62        78
#            4       0.86      0.83      0.84        75
#            5       0.68      0.67      0.68        78
#            6       0.63      0.61      0.62        36
#            7       0.57      0.69      0.62        36
#
#     accuracy                           0.70       491
#    macro avg       0.69      0.70      0.69       491
# weighted avg       0.71      0.70      0.71       491

# %% [markdown]
# Just for fun. You can explore on callbacks used in model.fit().\
# For resources, you can go to https://keras.io/api/callbacks/ and explore on your own. Or just chatgpt :)
# Now try the model using EarlyStopping callback, LearningRateScheduler callback and ModelCheckpoint callback.

# %%
#Have fun ..... you just completed the project

# %% [markdown]
# The timeline for this is 2 weeks. In the last two weeks, we will be exploring further concepts in AIML or doing some fun activities in the field. Look forward to it :)
